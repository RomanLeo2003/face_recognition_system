# %%
from deepface import DeepFace
import cv2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from deepface import DeepFace
#       2 import cv2
#
# File ~\anaconda3\envs\classification\lib\site-packages\deepface\DeepFace.py:14
#      12 from tqdm import tqdm
#      13 import cv2
# ---> 14 import tensorflow as tf
#      16 # package dependencies
#      17 from deepface.basemodels import (
#      18     VGGFace,
#      19     OpenFace,
#    (...)
#      26     SFace,
#      27 )
#
# File ~\anaconda3\envs\classification\lib\site-packages\tensorflow\__init__.py:52
#      50 from ._api.v2 import autograph
#      51 from ._api.v2 import bitwise
# ---> 52 from ._api.v2 import compat
#      53 from ._api.v2 import config
#      54 from ._api.v2 import data
#
# File ~\anaconda3\envs\classification\lib\site-packages\tensorflow\_api\v2\compat\__init__.py:37
#       3 """Compatibility functions.
# ...

# %%
DeepFace.stream(source=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 DeepFace.stream(source=0)
#
# NameError: name 'DeepFace' is not defined
